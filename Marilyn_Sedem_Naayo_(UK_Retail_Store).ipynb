# %% [markdown]
# # Data Scientist Project Case Study

# %% [markdown]
# ***This project relates to the United Kingdom only
#
# A leading retail company has reached out to us to help them make some data-driven decisions to help grow and differentiate their business. As part of this need, the CEO of the company has shared some of their transactional data to help with this discovery process. He has questions about what types of items should be placed close together on shelves for shelf optimization, some major items that should be ordered ahead of time, a forecast of revenue for the next year, what type of items should they run promotions on, and why. He’ll also appreciate any additional data-driven insights you can share to give them a competitive edge.
#
# As a data scientist assigned to this client to help with this task, kindly prepare a presentation outlining your findings and insights to the CEO. You'll also be required to host a technical session with the Data Science team of the company to share your methodology, code, and thinking process. Please bear in mind that they were skeptical about the CEO outsourcing this project to you so be prepared to share and explain your approaches.

# %% [markdown]
# ## **OBJECTIVES**
# 1. **shelf optimization**
# 2. **some major items that should be ordered ahead of time**
# 3. **a forecast of revenue for the next year**
# 4. **what type of items should they run promotions on, and why.**
# 5. **Additional data-driven insights to give them a competitive edge**

# %% [markdown]
# ### **BUSINESS QUESTIONS**

# %% [markdown]
# 1. **How many items are there?**
# 2. **What are the most purchased items?**
# 3. **What are the least purchased items?**
# 4. **How many customers are there?**
# 5. **Who are the top customers and what do they patronise?**
# 6. **On what days of the week are most sales made?**
# 7. **At what time of the day are the most sales made?**

# %% [markdown]
# ## IMPORTATION OF NECESSARY PACKAGES

# %%
# Data Handling
from datetime import datetime, date
import numpy as np
import pandas as pd
import datetime as dt

# Visualization
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.patches as mpatches
import seaborn as sns
import plotly.express as px

# Other Packages
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
#  ## DATA IMPORTATION

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Zach Levi and Associates/data.csv', parse_dates = ['InvoiceDate'],encoding = 'latin1' )

# %%
data.tail(20)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
# 541894    581587     22631             CIRCUS PARADE LUNCH BOX         12
# 541895    581587     22556       PLASTERS IN TIN CIRCUS PARADE         12
# 541896    581587     22555            PLASTERS IN TIN STRONGMAN        12
# 541897    581587     22728            ALARM CLOCK BAKELIKE PINK         4
# 541898    581587     22727            ALARM CLOCK BAKELIKE RED          4
# 541899    581587     22726           ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730           ALARM CLOCK BAKELIKE IVORY         4
# 541901    581587     22367      CHILDRENS APRON SPACEBOY DESIGN         8
# 541902    581587     22629                  SPACEBOY LUNCH BOX         12
# 541903    581587     23256          CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 541889 2011-12-09 12:31:00       1.95     15804.0  United Kingdom
# 541890 2011-12-09 12:49:00       2.95     13113.0  United Kingdom
# 541891 2011-12-09 12:49:00       1.25     13113.0  United Kingdom
# 541892 2011-12-09 12:49:00       8.95     13113.0  United Kingdom
# 541893 2011-12-09 12:49:00       7.08     13113.0  United Kingdom
# 541894 2011-12-09 12:50:00       1.95     12680.0          France
# 541895 2011-12-09 12:50:00       1.65     12680.0          France
# 541896 2011-12-09 12:50:00       1.65     12680.0          France
# 541897 2011-12-09 12:50:00       3.75     12680.0          France
# 541898 2011-12-09 12:50:00       3.75     12680.0          France
# 541899 2011-12-09 12:50:00       3.75     12680.0          France
# 541900 2011-12-09 12:50:00       3.75     12680.0          France
# 541901 2011-12-09 12:50:00       1.95     12680.0          France
# 541902 2011-12-09 12:50:00       1.95     12680.0          France
# 541903 2011-12-09 12:50:00       4.15     12680.0          France
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France

# %% [markdown]
# ## SANITY CHECKS AND DATA CLEANING

# %% [markdown]
# ### Column names

# %%
for columns in data.columns:
    print(columns)
# Out:
# InvoiceNo
# StockCode
# Description
# Quantity
# InvoiceDate
# UnitPrice
# CustomerID
# Country

# %%
# Changing the column names to increase legibility
data.rename(columns= {'InvoiceNo':'Invoice Number','StockCode':'Stock Code','Description':'Item Description',\
                      'InvoiceDate':'Timestamp','UnitPrice':'Unit Price','CustomerID':'Customer ID'}, inplace = True)

# %%
for col in data.columns:
    print(col)
# Out:
# Invoice Number
# Stock Code
# Item Description
# Quantity
# Timestamp
# Unit Price
# Customer ID
# Country

# %%
data.isna().sum()
# Out:
# Invoice Number           0
# Stock Code               0
# Item Description      1454
# Quantity                 0
# Timestamp                0
# Unit Price               0
# Customer ID         135080
# Country                  0
# dtype: int64

# %% [markdown]
# ### Data types contained in columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Invoice Number    541909 non-null  object
#  1   Stock Code        541909 non-null  object
#  2   Item Description  540455 non-null  object
#  3   Quantity          541909 non-null  int64
#  4   Timestamp         541909 non-null  datetime64[ns]
#  5   Unit Price        541909 non-null  float64
#  6   Customer ID       406829 non-null  float64
#  7   Country           541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
data = data.astype({'Customer ID':object})

# %%
# Ascertaining changes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Invoice Number    541909 non-null  object
#  1   Stock Code        541909 non-null  object
#  2   Item Description  540455 non-null  object
#  3   Quantity          541909 non-null  int64
#  4   Timestamp         541909 non-null  datetime64[ns]
#  5   Unit Price        541909 non-null  float64
#  6   Customer ID       406829 non-null  object
#  7   Country           541909 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ### Unique values per category

# %%
data.nunique()
# Out:
# Invoice Number      25900
# Stock Code           4070
# Item Description     4223
# Quantity              722
# Timestamp           23260
# Unit Price           1630
# Customer ID          4372
# Country                38
# dtype: int64

# %% [markdown]
# ##### Stock code has 4,070 unique values while Item Description has 4,223. Each stock code should relate to an item description, what is causing the disparity?

# %%
# There are 38 countries but the study is only focused on the UK.
# Checking data to ensure that the united kingdom is not represented in another way within the columns
data['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# ## Filtering for only UK Data

# %%
uk_retail = data[data['Country'] == 'United Kingdom']

# %%
uk_retail.head(10)
# Out:
#   Invoice Number Stock Code                     Item Description  Quantity  \
# 0         536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365      71053                  WHITE METAL LANTERN         6
# 2         536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365      22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365      21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366      22633               HAND WARMER UNION JACK         6
# 8         536366      22632            HAND WARMER RED POLKA DOT         6
# 9         536367      84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#             Timestamp  Unit Price Customer ID         Country
# 0 2010-12-01 08:26:00        2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00        7.65     17850.0  United Kingdom
# 6 2010-12-01 08:26:00        4.25     17850.0  United Kingdom
# 7 2010-12-01 08:28:00        1.85     17850.0  United Kingdom
# 8 2010-12-01 08:28:00        1.85     17850.0  United Kingdom
# 9 2010-12-01 08:34:00        1.69     13047.0  United Kingdom

# %% [markdown]
#  ### Checking for unique values within columns

# %%
uk_retail.nunique()
# Out:
# Invoice Number      23494
# Stock Code           4065
# Item Description     4202
# Quantity              715
# Timestamp           21220
# Unit Price           1574
# Customer ID          3950
# Country                 1
# dtype: int64

# %% [markdown]
#  ##### The data is from the United Kingdom only and it contains 23,494 distinct sales to 3,950 different customers.

# %% [markdown]
# ### Data Types contained in the columns of UK_Retail Data

# %%
uk_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 495478 entries, 0 to 541893
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Invoice Number    495478 non-null  object
#  1   Stock Code        495478 non-null  object
#  2   Item Description  494024 non-null  object
#  3   Quantity          495478 non-null  int64
#  4   Timestamp         495478 non-null  datetime64[ns]
#  5   Unit Price        495478 non-null  float64
#  6   Customer ID       361878 non-null  object
#  7   Country           495478 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 34.0+ MB

# %% [markdown]
# ### Checking for Null Values

# %%
uk_retail.isna().sum()
# Out:
# Invoice Number           0
# Stock Code               0
# Item Description      1454
# Quantity                 0
# Timestamp                0
# Unit Price               0
# Customer ID         133600
# Country                  0
# dtype: int64

# %% [markdown]
# ##### There are 133,600 rows with missing Customer ID's and 1,454 rows with missing item descriptions
# ##### The null values are found in Customer ID and Item Description columns which both contain categorical data

# %% [markdown]
# ###Fill null Item Description Values

# %%
from collections import Counter
missing_descriptions = uk_retail[uk_retail['Item Description'].isna()][['Stock Code']].drop_duplicates()
all_desc = uk_retail[~uk_retail['Item Description'].isna()][['Stock Code', 'Item Description']]

def get_desc(gr):
    c = Counter(gr['Item Description'].values)
    return c.most_common(1)[0][0]
new_desc = all_desc.groupby('Stock Code').apply(get_desc)

for stock in new_desc.index.values:
    uk_retail.loc[uk_retail['Stock Code']==stock, 'Item Description'] = new_desc.loc[stock]

# %%
uk_retail.isna().sum()
# Out:
# Invoice Number           0
# Stock Code               0
# Item Description       115
# Quantity                 0
# Timestamp                0
# Unit Price               0
# Customer ID         133600
# Country                  0
# dtype: int64

# %% [markdown]
# ### Summary Statistics of UK_Retail Data

# %%
uk_retail.describe()
# Out:
#             Quantity                      Timestamp     Unit Price
# count  495478.000000                         495478  495478.000000
# mean        8.605486  2011-07-04 05:01:41.098131456       4.532422
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-27 12:06:00       1.250000
# 50%         3.000000            2011-07-19 11:47:00       2.100000
# 75%        10.000000            2011-10-20 10:41:00       4.130000
# max     80995.000000            2011-12-09 12:49:00   38970.000000
# std       227.588756                            NaN      99.315438

# %% [markdown]
# ##### The minimum quantity is -80,995 and the highest is 80,995. The minimum unit price is -11062.06 and the highest is 38,970

# %%
uk_retail.describe(include = object)
# Out:
#        Invoice Number Stock Code                    Item Description  \
# count          495478     495478                              495363
# unique          23494       4065                                3815
# top            573585     85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq             1114       2215                                2282
#
#         Customer ID         Country
# count      361878.0          495478
# unique       3950.0               1
# top         17841.0  United Kingdom
# freq         7983.0          495478

# %% [markdown]
# ### Dropping duplicates

# %%
uk_retail.duplicated().sum()
# Out:
# 5180

# %%
uk_retail = uk_retail.drop_duplicates()

# %%
uk_retail.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Inspecting negative unit price and quantity data

# %% [markdown]
# #### Unit Price Data

# %%
uk_retail[uk_retail['Unit Price']<0]
# Out:
#        Invoice Number Stock Code Item Description  Quantity  \
# 299983        A563186          B  Adjust bad debt         1
# 299984        A563187          B  Adjust bad debt         1
#
#                  Timestamp  Unit Price Customer ID         Country
# 299983 2011-08-12 14:51:00   -11062.06         NaN  United Kingdom
# 299984 2011-08-12 14:52:00   -11062.06         NaN  United Kingdom

# %% [markdown]
# ##### The above are non-sales related and will therefore be dropped

# %%
# Dropping negative unit price values
price_under_zero = uk_retail[uk_retail['Unit Price']<0].index
uk_retail=uk_retail.drop(price_under_zero)
uk_retail
# Out:
#        Invoice Number Stock Code                     Item Description  \
# 0              536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1              536365      71053                  WHITE METAL LANTERN
# 2              536365     84406B       CREAM CUPID HEARTS COAT HANGER
# 3              536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4              536365     84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...               ...        ...                                  ...
# 541889         581585      22466       FAIRY TALE COTTAGE NIGHT LIGHT
# 541890         581586      22061  LARGE CAKE STAND  HANGING STRAWBERY
# 541891         581586      23275     SET OF 3 HANGING OWLS OLLIE BEAK
# 541892         581586      21217        RED RETROSPOT ROUND CAKE TINS
# 541893         581586      20685                DOORMAT RED RETROSPOT
#
#         Quantity           Timestamp  Unit Price Customer ID         Country
# 0              6 2010-12-01 08:26:00        2.55     17850.0  United Kingdom
# 1              6 2010-12-01 08:26:00        3.39     17850.0  United Kingdom
# 2              8 2010-12-01 08:26:00        2.75     17850.0  United Kingdom
# 3              6 2010-12-01 08:26:00        3.39     17850.0  United Kingdom
# 4              6 2010-12-01 08:26:00        3.39     17850.0  United Kingdom
# ...          ...                 ...         ...         ...             ...
# 541889        12 2011-12-09 12:31:00        1.95     15804.0  United Kingdom
# 541890         8 2011-12-09 12:49:00        2.95     13113.0  United Kingdom
# 541891        24 2011-12-09 12:49:00        1.25     13113.0  United Kingdom
# 541892        24 2011-12-09 12:49:00        8.95     13113.0  United Kingdom
# 541893        10 2011-12-09 12:49:00        7.08     13113.0  United Kingdom
#
# [490296 rows x 8 columns]

# %%
# Making sure the rows have been removed
uk_retail[uk_retail['Unit Price']<0]
# Out:
# Empty DataFrame
# Columns: [Invoice Number, Stock Code, Item Description, Quantity, Timestamp, Unit Price, Customer ID, Country]
# Index: []

# %% [markdown]
# ### Resolve Zero Unit Prices

# %%
uk_retail[uk_retail['Unit Price']==0]
# Out:
#        Invoice Number Stock Code                     Item Description  \
# 622            536414      22139     RETROSPOT TEA SET CERAMIC 11 PC
# 1970           536545      21134                                  NaN
# 1971           536546      22145                                  NaN
# 1972           536547      37509           NEW ENGLAND MUG W GIFT BOX
# 1987           536549     85226A                                  NaN
# ...               ...        ...                                  ...
# 536981         581234      72817  SET OF 2 CHRISTMAS DECOUPAGE CANDLE
# 538504         581406     46000M         POLYESTER FILLER PAD 45x45cm
# 538505         581406     46000S         POLYESTER FILLER PAD 40x40cm
# 538554         581408      85175                CACTI T-LIGHT CANDLES
# 538919         581422      23169             CLASSIC GLASS COOKIE JAR
#
#         Quantity           Timestamp  Unit Price Customer ID         Country
# 622           56 2010-12-01 11:52:00         0.0         NaN  United Kingdom
# 1970           1 2010-12-01 14:32:00         0.0         NaN  United Kingdom
# 1971           1 2010-12-01 14:33:00         0.0         NaN  United Kingdom
# 1972           1 2010-12-01 14:33:00         0.0         NaN  United Kingdom
# 1987           1 2010-12-01 14:34:00         0.0         NaN  United Kingdom
# ...          ...                 ...         ...         ...             ...
# 536981        27 2011-12-08 10:33:00         0.0         NaN  United Kingdom
# 538504       240 2011-12-08 13:58:00         0.0         NaN  United Kingdom
# 538505       300 2011-12-08 13:58:00         0.0         NaN  United Kingdom
# 538554        20 2011-12-08 14:06:00         0.0         NaN  United Kingdom
# 538919      -235 2011-12-08 15:24:00         0.0         NaN  United Kingdom
#
# [2492 rows x 8 columns]

# %%
zero_unit_priced_stock = uk_retail[uk_retail['Unit Price'] <= 0.0]\
['Stock Code'].drop_duplicates()
stock_unit_price = uk_retail[uk_retail['Unit Price'] != 0].groupby('Stock Code').agg({'Unit Price': [max, min, 'mean']})
stock_unit_price.columns = ["_".join(x) for x in stock_unit_price.columns.ravel()]
for stock in zero_unit_priced_stock.values:
    if stock in stock_unit_price.index.values:
        uk_retail.loc[(uk_retail['Stock Code'] == stock) & (uk_retail['Unit Price'] == 0), 'Unit Price'] = stock_unit_price.loc[stock, 'Unit Price_mean'].round(2)

# %%
uk_retail[uk_retail['Unit Price']==0]
# Out:
#        Invoice Number Stock Code        Item Description  Quantity  \
# 1970           536545      21134                     NaN         1
# 1971           536546      22145                     NaN         1
# 1987           536549     85226A                     NaN         1
# 1988           536550      85044                     NaN         1
# 2024           536552      20950                     NaN         1
# ...               ...        ...                     ...       ...
# 431378         573593    79323LP  Unsaleable, destroyed.     -2618
# 431380         573595     79323S  Unsaleable, destroyed.      -674
# 431382         573597      79341  Unsaleable, destroyed.      -905
# 431383         573598     79342B  Unsaleable, destroyed.     -1128
# 497301         578360     84971L                     NaN         2
#
#                  Timestamp  Unit Price Customer ID         Country
# 1970   2010-12-01 14:32:00         0.0         NaN  United Kingdom
# 1971   2010-12-01 14:33:00         0.0         NaN  United Kingdom
# 1987   2010-12-01 14:34:00         0.0         NaN  United Kingdom
# 1988   2010-12-01 14:34:00         0.0         NaN  United Kingdom
# 2024   2010-12-01 14:34:00         0.0         NaN  United Kingdom
# ...                    ...         ...         ...             ...
# 431378 2011-10-31 15:16:00         0.0         NaN  United Kingdom
# 431380 2011-10-31 15:17:00         0.0         NaN  United Kingdom
# 431382 2011-10-31 15:18:00         0.0         NaN  United Kingdom
# 431383 2011-10-31 15:18:00         0.0         NaN  United Kingdom
# 497301 2011-11-24 10:36:00         0.0         NaN  United Kingdom
#
# [139 rows x 8 columns]

# %%
uk_retail[uk_retail['Unit Price'] == 0.0]['Customer ID'].reset_index()
# Out:
#       index Customer ID
# 0      1970         NaN
# 1      1971         NaN
# 2      1987         NaN
# 3      1988         NaN
# 4      2024         NaN
# ..      ...         ...
# 134  431378         NaN
# 135  431380         NaN
# 136  431382         NaN
# 137  431383         NaN
# 138  497301         NaN
#
# [139 rows x 2 columns]

# %% [markdown]
# All the remaining zero Unit Prices have no customer ID's.

# %%
uk_retail[uk_retail['Unit Price'] <= 0.0]['Item Description'].value_counts(dropna=False).reset_index()
# Out:
#                      Item Description  count
# 0                                 NaN    115
# 1              Unsaleable, destroyed.      6
# 2                         thrown away      5
# 3                                ebay      3
# 4                          adjustment      2
# 5                             damages      1
# 6                          throw away      1
# 7             thrown away-can't sell.      1
# 8              thrown away-can't sell      1
# 9                   Thrown away-rusty      1
# 10  TRAVEL CARD WALLET DOTCOMGIFTSHOP      1
# 11         PADS TO MATCH ALL CUSHIONS      1
# 12                    Found by jackie      1

# %% [markdown]
# #####The remaining zero prices seem to consist of items which cannot be sold (except TRAVEL CARD WALLET DOTCOMGIFTSHOP and PADS TO MATCH ALL CUSHIONS which seem to have been given for free) and items with no description. Also all these transactions have no Customer ID's. This means that they neither contribute to the sales value nor give information on the buying practices of customers. These will be dropped.

# %%
# Dropping unit price = 0
price_zero = uk_retail[uk_retail['Unit Price']==0].index
uk_retail=uk_retail.drop(price_zero)

# %%
uk_retail[uk_retail['Unit Price']==0]
# Out:
# Empty DataFrame
# Columns: [Invoice Number, Stock Code, Item Description, Quantity, Timestamp, Unit Price, Customer ID, Country]
# Index: []

# %% [markdown]
# ### FEATURE ENGINEERING

# %% [markdown]
# ### Creating a Sales column

# %%
uk_retail['Sales'] = (uk_retail['Unit Price'])*(uk_retail['Quantity'])

# %%
uk_retail
# Out:
#        Invoice Number Stock Code                     Item Description  \
# 0              536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1              536365      71053                  WHITE METAL LANTERN
# 2              536365     84406B       CREAM CUPID HEARTS COAT HANGER
# 3              536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4              536365     84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...               ...        ...                                  ...
# 541889         581585      22466       FAIRY TALE COTTAGE NIGHT LIGHT
# 541890         581586      22061  LARGE CAKE STAND  HANGING STRAWBERY
# 541891         581586      23275     SET OF 3 HANGING OWLS OLLIE BEAK
# 541892         581586      21217        RED RETROSPOT ROUND CAKE TINS
# 541893         581586      20685                DOORMAT RED RETROSPOT
#
#         Quantity           Timestamp  Unit Price Customer ID         Country  \
# 0              6 2010-12-01 08:26:00        2.55     17850.0  United Kingdom
# 1              6 2010-12-01 08:26:00        3.39     17850.0  United Kingdom
# 2              8 2010-12-01 08:26:00        2.75     17850.0  United Kingdom
# 3              6 2010-12-01 08:26:00        3.39     17850.0  United Kingdom
# 4              6 2010-12-01 08:26:00        3.39     17850.0  United Kingdom
# ...          ...                 ...         ...         ...             ...
# 541889        12 2011-12-09 12:31:00        1.95     15804.0  United Kingdom
# 541890         8 2011-12-09 12:49:00        2.95     13113.0  United Kingdom
# 541891        24 2011-12-09 12:49:00        1.25     13113.0  United Kingdom
# 541892        24 2011-12-09 12:49:00        8.95     13113.0  United Kingdom
# 541893        10 2011-12-09 12:49:00        7.08     13113.0  United Kingdom
#
#          Sales
# 0        15.30
# 1        20.34
# 2        22.00
# 3        20.34
# 4        20.34
# ...        ...
# 541889   23.40
# 541890   23.60
# 541891   30.00
# 541892  214.80
# 541893   70.80
#
# [490157 rows x 9 columns]

# %% [markdown]
# ### Extracting time, date, day of the week and month

# %%
# Time
uk_retail['Invoice Time'] = uk_retail['Timestamp'].dt.time
# Date
uk_retail['Invoice Date'] = uk_retail['Timestamp'].dt.date
# Day of the week
uk_retail['Day of the week'] = uk_retail['Timestamp'].dt.day_name()
# Month
uk_retail['Month'] = uk_retail['Timestamp'].dt.month_name()
# Year
uk_retail['Year'] = uk_retail['Timestamp'].dt.year

# %%
uk_retail.head(20)
# Out:
#    Invoice Number Stock Code                     Item Description  Quantity  \
# 0          536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365      71053                  WHITE METAL LANTERN         6
# 2          536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5          536365      22752         SET 7 BABUSHKA NESTING BOXES         2
# 6          536365      21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7          536366      22633               HAND WARMER UNION JACK         6
# 8          536366      22632            HAND WARMER RED RETROSPOT         6
# 9          536367      84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10         536367      22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11         536367      22748            POPPY'S PLAYHOUSE KITCHEN         6
# 12         536367      22749    FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 13         536367      22310              IVORY KNITTED MUG COSY          6
# 14         536367      84969   BOX OF 6 ASSORTED COLOUR TEASPOONS         6
# 15         536367      22623        BOX OF VINTAGE JIGSAW BLOCKS          3
# 16         536367      22622       BOX OF VINTAGE ALPHABET BLOCKS         2
# 17         536367      21754             HOME BUILDING BLOCK WORD         3
# 18         536367      21755             LOVE BUILDING BLOCK WORD         3
# 19         536367      21777          RECIPE BOX WITH METAL HEART         4
#
#              Timestamp  Unit Price Customer ID         Country  Sales  \
# 0  2010-12-01 08:26:00        2.55     17850.0  United Kingdom  15.30
# 1  2010-12-01 08:26:00        3.39     17850.0  United Kingdom  20.34
# 2  2010-12-01 08:26:00        2.75     17850.0  United Kingdom  22.00
# 3  2010-12-01 08:26:00        3.39     17850.0  United Kingdom  20.34
# 4  2010-12-01 08:26:00        3.39     17850.0  United Kingdom  20.34
# 5  2010-12-01 08:26:00        7.65     17850.0  United Kingdom  15.30
# 6  2010-12-01 08:26:00        4.25     17850.0  United Kingdom  25.50
# 7  2010-12-01 08:28:00        1.85     17850.0  United Kingdom  11.10
# 8  2010-12-01 08:28:00        1.85     17850.0  United Kingdom  11.10
# 9  2010-12-01 08:34:00        1.69     13047.0  United Kingdom  54.08
# 10 2010-12-01 08:34:00        2.10     13047.0  United Kingdom  12.60
# 11 2010-12-01 08:34:00        2.10     13047.0  United Kingdom  12.60
# 12 2010-12-01 08:34:00        3.75     13047.0  United Kingdom  30.00
# 13 2010-12-01 08:34:00        1.65     13047.0  United Kingdom   9.90
# 14 2010-12-01 08:34:00        4.25     13047.0  United Kingdom  25.50
# 15 2010-12-01 08:34:00        4.95     13047.0  United Kingdom  14.85
# 16 2010-12-01 08:34:00        9.95     13047.0  United Kingdom  19.90
# 17 2010-12-01 08:34:00        5.95     13047.0  United Kingdom  17.85
# 18 2010-12-01 08:34:00        5.95     13047.0  United Kingdom  17.85
# 19 2010-12-01 08:34:00        7.95     13047.0  United Kingdom  31.80
#
#    Invoice Time Invoice Date Day of the week     Month  Year
# 0      08:26:00   2010-12-01       Wednesday  December  2010
# 1      08:26:00   2010-12-01       Wednesday  December  2010
# 2      08:26:00   2010-12-01       Wednesday  December  2010
# 3      08:26:00   2010-12-01       Wednesday  December  2010
# 4      08:26:00   2010-12-01       Wednesday  December  2010
# 5      08:26:00   2010-12-01       Wednesday  December  2010
# 6      08:26:00   2010-12-01       Wednesday  December  2010
# 7      08:28:00   2010-12-01       Wednesday  December  2010
# 8      08:28:00   2010-12-01       Wednesday  December  2010
# 9      08:34:00   2010-12-01       Wednesday  December  2010
# 10     08:34:00   2010-12-01       Wednesday  December  2010
# 11     08:34:00   2010-12-01       Wednesday  December  2010
# 12     08:34:00   2010-12-01       Wednesday  December  2010
# 13     08:34:00   2010-12-01       Wednesday  December  2010
# 14     08:34:00   2010-12-01       Wednesday  December  2010
# 15     08:34:00   2010-12-01       Wednesday  December  2010
# 16     08:34:00   2010-12-01       Wednesday  December  2010
# 17     08:34:00   2010-12-01       Wednesday  December  2010
# 18     08:34:00   2010-12-01       Wednesday  December  2010
# 19     08:34:00   2010-12-01       Wednesday  December  2010

# %%
uk_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 490157 entries, 0 to 541893
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Invoice Number    490157 non-null  object
#  1   Stock Code        490157 non-null  object
#  2   Item Description  490157 non-null  object
#  3   Quantity          490157 non-null  int64
#  4   Timestamp         490157 non-null  datetime64[ns]
#  5   Unit Price        490157 non-null  float64
#  6   Customer ID       356725 non-null  object
#  7   Country           490157 non-null  object
#  8   Sales             490157 non-null  float64
#  9   Invoice Time      490157 non-null  object
#  10  Invoice Date      490157 non-null  object
#  11  Day of the week   490157 non-null  object
#  12  Month             490157 non-null  object
#  13  Year              490157 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(1), object(9)
# memory usage: 54.2+ MB

# %%
# Change invoice date to datetime
uk_retail['Invoice Date'] = pd.to_datetime(uk_retail['Invoice Date'])

# %% [markdown]
# ## Further analysis of data using new set of columns

# %%
uk_retail[uk_retail['Sales']<0].sort_values(by='Sales',ascending=True)
# Out:
#        Invoice Number Stock Code                    Item Description  \
# 540422        C581484      23843         PAPER CRAFT , LITTLE BIRDIE
# 61624         C541433      23166      MEDIUM CERAMIC TOP STORAGE JAR
# 222681        C556445          M                              Manual
# 431381         573596     79323W                 WHITE CHERRY LIGHTS
# 524602        C580605  AMAZONFEE                          AMAZON FEE
# ...               ...        ...                                 ...
# 199723        C554100      16235  RECYCLED PENCIL WITH RABBIT ERASER
# 440246        C574524      84929  ASSTD FRUIT+FLOWERS FRIDGE MAGNETS
# 329372        C565843     85194S     HANGING SPRING FLOWER EGG SMALL
# 72727         C542256      21883                    STARS GIFT TAPE
# 504697        C578991      85204        HANGING WOOD AND FELT FLOWER
#
#         Quantity           Timestamp  Unit Price Customer ID         Country  \
# 540422    -80995 2011-12-09 09:27:00        2.08     16446.0  United Kingdom
# 61624     -74215 2011-01-18 10:17:00        1.04     12346.0  United Kingdom
# 222681        -1 2011-06-10 15:31:00    38970.00     15098.0  United Kingdom
# 431381     -4830 2011-10-31 15:17:00        6.75         NaN  United Kingdom
# 524602        -1 2011-12-05 11:36:00    17836.46         NaN  United Kingdom
# ...          ...                 ...         ...         ...             ...
# 199723        -1 2011-05-22 13:27:00        0.21     15555.0  United Kingdom
# 440246        -1 2011-11-04 13:53:00        0.19     17841.0  United Kingdom
# 329372        -1 2011-09-07 12:15:00        0.19     14606.0  United Kingdom
# 72727         -1 2011-01-26 17:04:00        0.19     17722.0  United Kingdom
# 504697        -1 2011-11-27 15:31:00        0.12     15555.0  United Kingdom
#
#             Sales Invoice Time Invoice Date Day of the week      Month  Year
# 540422 -168469.60     09:27:00   2011-12-09          Friday   December  2011
# 61624   -77183.60     10:17:00   2011-01-18         Tuesday    January  2011
# 222681  -38970.00     15:31:00   2011-06-10          Friday       June  2011
# 431381  -32602.50     15:17:00   2011-10-31          Monday    October  2011
# 524602  -17836.46     11:36:00   2011-12-05          Monday   December  2011
# ...           ...          ...          ...             ...        ...   ...
# 199723      -0.21     13:27:00   2011-05-22          Sunday        May  2011
# 440246      -0.19     13:53:00   2011-11-04          Friday   November  2011
# 329372      -0.19     12:15:00   2011-09-07       Wednesday  September  2011
# 72727       -0.19     17:04:00   2011-01-26       Wednesday    January  2011
# 504697      -0.12     15:31:00   2011-11-27          Sunday   November  2011
#
# [9040 rows x 14 columns]

# %% [markdown]
# Since the negative unit price values have been removed, the above dataset represents the negative quantities.
# Also all Discount item descriptions have quantities below zero. This makes it easy to investigate discount amounts and during the addition of Sales these will also be deductions of the discounts from the total Sales.

# %% [markdown]
# ###Null Values in the Customer ID columns

# %%
uk_retail[uk_retail['Sales']<0]
# Out:
#        Invoice Number Stock Code                  Item Description  Quantity  \
# 141           C536379          D                          Discount        -1
# 154           C536383     35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235           C536391      22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236           C536391      21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237           C536391      21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...               ...        ...                               ...       ...
# 540449        C581490      23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541        C581499          M                            Manual        -1
# 541715        C581568      21258        VICTORIAN SEWING BOX LARGE        -5
# 541716        C581569      84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717        C581569      20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                  Timestamp  Unit Price Customer ID         Country   Sales  \
# 141    2010-12-01 09:41:00       27.50     14527.0  United Kingdom  -27.50
# 154    2010-12-01 09:49:00        4.65     15311.0  United Kingdom   -4.65
# 235    2010-12-01 10:24:00        1.65     17548.0  United Kingdom  -19.80
# 236    2010-12-01 10:24:00        0.29     17548.0  United Kingdom   -6.96
# 237    2010-12-01 10:24:00        0.29     17548.0  United Kingdom   -6.96
# ...                    ...         ...         ...             ...     ...
# 540449 2011-12-09 09:57:00        0.83     14397.0  United Kingdom   -9.13
# 541541 2011-12-09 10:28:00      224.69     15498.0  United Kingdom -224.69
# 541715 2011-12-09 11:57:00       10.95     15311.0  United Kingdom  -54.75
# 541716 2011-12-09 11:58:00        1.25     17315.0  United Kingdom   -1.25
# 541717 2011-12-09 11:58:00        1.25     17315.0  United Kingdom   -6.25
#
#        Invoice Time Invoice Date Day of the week     Month  Year
# 141        09:41:00   2010-12-01       Wednesday  December  2010
# 154        09:49:00   2010-12-01       Wednesday  December  2010
# 235        10:24:00   2010-12-01       Wednesday  December  2010
# 236        10:24:00   2010-12-01       Wednesday  December  2010
# 237        10:24:00   2010-12-01       Wednesday  December  2010
# ...             ...          ...             ...       ...   ...
# 540449     09:57:00   2011-12-09          Friday  December  2011
# 541541     10:28:00   2011-12-09          Friday  December  2011
# 541715     11:57:00   2011-12-09          Friday  December  2011
# 541716     11:58:00   2011-12-09          Friday  December  2011
# 541717     11:58:00   2011-12-09          Friday  December  2011
#
# [9040 rows x 14 columns]

# %% [markdown]
# These seem to be some sales as well as item cancellations which have not been assigned customer ID's.
# These rows with negative sales values and no customer ID's have no unique values such as invoice numbers or stock codes which connects them to the existing Customers ID's.

# %% [markdown]
# What is the Total of sales for the duration?

# %%
# Total Sales
total_sales = uk_retail['Sales'].sum()
print("Total Sales of UK Retail Store for the duration is {}".format(total_sales))
# Out:
# Total Sales of UK Retail Store for the duration is 8617873.304000001

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %% [markdown]
# ### Sales Distribution

# %%
# Histogram
plt.figure(figsize=(10, 6))
plt.hist(uk_retail['Sales'], bins=50, color='green', edgecolor='white')
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# Boxplot
plt.figure(figsize=(10, 6))
plt.boxplot(uk_retail['Sales'])
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.show()

# %% [markdown]
# Majority of the sales fall within a certain range represented by the peak of the histogram and the area of high density on the boxplot. As displayed, majority of the sales are in the lower values, and the boxplot shows a lot more outliers in the higher price range than in the negative range.

# %% [markdown]
# ### Unit Price Distribution

# %%
# Histogram
plt.figure(figsize=(10, 6))
plt.hist(uk_retail['Unit Price'], bins= 50,color='skyblue', edgecolor='black')
plt.title('Distribution of Prices')
plt.xlabel('Unit Price')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# Boxplot
plt.figure(figsize=(10, 6))
plt.boxplot(uk_retail['Unit Price'])
plt.title('Distribution of Unit Prices')
plt.xlabel('Unit Price')
plt.show()

# %% [markdown]
# Majority of Unit prices are also found in the lower portion of the prices. Prices are clustered between 0 and 4,000. And the highest price is about 15,000.

# %% [markdown]
# ### Quantity Distribution

# %%
# Histplot
plt.figure(figsize=(10, 6))
plt.hist(uk_retail['Quantity'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Order Quantities')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# Boxplot
plt.figure(figsize=(10, 6))
plt.boxplot(uk_retail['Quantity'])
plt.title('Distribution of order Quantities')
plt.xlabel('Quantity')
plt.show()

# %% [markdown]
# ###BIVARIATE ANALYSIS

# %% [markdown]
# ### Sales Trend over Duration

# %%
# Group the data by date and calculate the total sales
daily_sales = uk_retail.groupby('Invoice Date')['Sales'].sum().reset_index()

# Create a time series plot
fig = px.line(daily_sales, x='Invoice Date', y='Sales')
fig.update_layout(title='Trend of Sales Over Time', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0988e2dd-8f42-4fa2-83f3-f5012a7811f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0988e2dd-8f42-4fa2-83f3-f5012a7811f8")) {                    Plotly.newPlot(                        "0988e2dd-8f42-4fa2-83f3-f5012a7811f8",                        [{"hovertemplate":"Invoice Date=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2010-12-01T00:00:00","2010-12-02T00:00:00","2010-12-03T00:00:00","2010-12-05T00:00:00","2010-12-06T00:00:00","2010-12-07T00:00:00","2010-12-08T00:00:00","2010-12-09T00:00:00","2010-12-10T00:00:00","2010-12-12T00:00:00","2010-12-13T00:00:00","2010-12-14T00:00:00","2010-12-15T00:00:00","2010-12-16T00:00:00","2010-12-17T00:00:00","2010-12-19T00:00:00","2010-12-20T00:00:00","2010-12-21T00:00:00","2010-12-22T00:00:00","2010-12-23T00:00:00","2011-01-04T00:00:00","2011-01-05T00:00:00","2011-01-06T00:00:00","2011-01-07T00:00:00","2011-01-09T00:00:00","2011-01-10T00:00:00","2011-01-11T00:00:00","2011-01-12T00:00:00","2011-01-13T00:00:00","2011-01-14T00:00:00","2011-01-16T00:00:00","2011-01-17T00:00:00","2011-01-18T00:00:00","2011-01-19T00:00:00","2011-01-20T00:00:00","2011-01-21T00:00:00","2011-01-23T00:00:00","2011-01-24T00:00:00","2011-01-25T00:00:00","2011-01-26T00:00:00","2011-01-27T00:00:00","2011-01-28T00:00:00","2011-01-30T00:00:00","2011-01-31T00:00:00","2011-02-01T00:00:00","2011-02-02T00:00:00","2011-02-03T00:00:00","2011-02-04T00:00:00","2011-02-06T00:00:00","2011-02-07T00:00:00","2011-02-08T00:00:00","2011-02-09T00:00:00","2011-02-10T00:00:00","2011-02-11T00:00:00","2011-02-13T00:00:00","2011-02-14T00:00:00","2011-02-15T00:00:00","2011-02-16T00:00:00","2011-02-17T00:00:00","2011-02-18T00:00:00","2011-02-20T00:00:00","2011-02-21T00:00:00","2011-02-22T00:00:00","2011-02-23T00:00:00","2011-02-24T00:00:00","2011-02-25T00:00:00","2011-02-27T00:00:00","2011-02-28T00:00:00","2011-03-01T00:00:00","2011-03-02T00:00:00","2011-03-03T00:00:00","2011-03-04T00:00:00","2011-03-06T00:00:00","2011-03-07T00:00:00","2011-03-08T00:00:00","2011-03-09T00:00:00","2011-03-10T00:00:00","2011-03-11T00:00:00","2011-03-13T00:00:00","2011-03-14T00:00:00","2011-03-15T00:00:00","2011-03-16T00:00:00","2011-03-17T00:00:00","2011-03-18T00:00:00","2011-03-20T00:00:00","2011-03-21T00:00:00","2011-03-22T00:00:00","2011-03-23T00:00:00","2011-03-24T00:00:00","2011-03-25T00:00:00","2011-03-27T00:00:00","2011-03-28T00:00:00","2011-03-29T00:00:00","2011-03-30T00:00:00","2011-03-31T00:00:00","2011-04-01T00:00:00","2011-04-03T00:00:00","2011-04-04T00:00:00","2011-04-05T00:00:00","2011-04-06T00:00:00","2011-04-07T00:00:00","2011-04-08T00:00:00","2011-04-10T00:00:00","2011-04-11T00:00:00","2011-04-12T00:00:00","2011-04-13T00:00:00","2011-04-14T00:00:00","2011-04-15T00:00:00","2011-04-17T00:00:00","2011-04-18T00:00:00","2011-04-19T00:00:00","2011-04-20T00:00:00","2011-04-21T00:00:00","2011-04-26T00:00:00","2011-04-27T00:00:00","2011-04-28T00:00:00","2011-05-01T00:00:00","2011-05-03T00:00:00","2011-05-04T00:00:00","2011-05-05T00:00:00","2011-05-06T00:00:00","2011-05-08T00:00:00","2011-05-09T00:00:00","2011-05-10T00:00:00","2011-05-11T00:00:00","2011-05-12T00:00:00","2011-05-13T00:00:00","2011-05-15T00:00:00","2011-05-16T00:00:00","2011-05-17T00:00:00","2011-05-18T00:00:00","2011-05-19T00:00:00","2011-05-20T00:00:00","2011-05-22T00:00:00","2011-05-23T00:00:00","2011-05-24T00:00:00","2011-05-25T00:00:00","2011-05-26T00:00:00","2011-05-27T00:00:00","2011-05-29T00:00:00","2011-05-31T00:00:00","2011-06-01T00:00:00","2011-06-02T00:00:00","2011-06-03T00:00:00","2011-06-05T ...

# %%
# Group the data by time and calculate the average sales
day_time_sales = uk_retail.groupby('Invoice Time')['Sales'].mean().reset_index()

# Create a time series plot with slider
fig = px.line(day_time_sales, x='Invoice Time', y='Sales')
fig.update_layout(title='Trend of Average Sales Over Time of Day', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a285af51-b6de-43a8-b5b7-363502c28c31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a285af51-b6de-43a8-b5b7-363502c28c31")) {                    Plotly.newPlot(                        "a285af51-b6de-43a8-b5b7-363502c28c31",                        [{"hovertemplate":"Invoice Time=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["06:10:00","06:12:00","06:14:00","06:15:00","06:19:00","06:20:00","06:21:00","06:22:00","06:25:00","06:26:00","06:28:00","06:29:00","06:30:00","06:31:00","06:33:00","06:34:00","06:38:00","06:39:00","07:35:00","07:37:00","07:38:00","07:42:00","07:43:00","07:46:00","07:48:00","07:49:00","07:51:00","07:52:00","07:53:00","07:56:00","07:57:00","07:58:00","08:00:00","08:02:00","08:03:00","08:04:00","08:05:00","08:06:00","08:07:00","08:08:00","08:09:00","08:10:00","08:11:00","08:12:00","08:13:00","08:14:00","08:15:00","08:16:00","08:17:00","08:18:00","08:19:00","08:20:00","08:21:00","08:22:00","08:23:00","08:24:00","08:25:00","08:26:00","08:27:00","08:28:00","08:29:00","08:30:00","08:31:00","08:32:00","08:33:00","08:34:00","08:35:00","08:36:00","08:37:00","08:38:00","08:39:00","08:40:00","08:41:00","08:42:00","08:43:00","08:44:00","08:45:00","08:46:00","08:47:00","08:48:00","08:49:00","08:50:00","08:51:00","08:52:00","08:53:00","08:54:00","08:55:00","08:56:00","08:57:00","08:58:00","08:59:00","09:00:00","09:01:00","09:02:00","09:03:00","09:04:00","09:05:00","09:06:00","09:07:00","09:08:00","09:09:00","09:10:00","09:11:00","09:12:00","09:13:00","09:14:00","09:15:00","09:16:00","09:17:00","09:18:00","09:19:00","09:20:00","09:21:00","09:22:00","09:23:00","09:24:00","09:25:00","09:26:00","09:27:00","09:28:00","09:29:00","09:30:00","09:31:00","09:32:00","09:33:00","09:34:00","09:35:00","09:36:00","09:37:00","09:38:00","09:39:00","09:40:00","09:41:00","09:42:00","09:43:00","09:44:00","09:45:00","09:46:00","09:47:00","09:48:00","09:49:00","09:50:00","09:51:00","09:52:00","09:53:00","09:54:00","09:55:00","09:56:00","09:57:00","09:58:00","09:59:00","10:00:00","10:01:00","10:02:00","10:03:00","10:04:00","10:05:00","10:06:00","10:07:00","10:08:00","10:09:00","10:10:00","10:11:00","10:12:00","10:13:00","10:14:00","10:15:00","10:16:00","10:17:00","10:18:00","10:19:00","10:20:00","10:21:00","10:22:00","10:23:00","10:24:00","10:25:00","10:26:00","10:27:00","10:28:00","10:29:00","10:30:00","10:31:00","10:32:00","10:33:00","10:34:00","10:35:00","10:36:00","10:37:00","10:38:00","10:39:00","10:40:00","10:41:00","10:42:00","10:43:00","10:44:00","10:45:00","10:46:00","10:47:00","10:48:00","10:49:00","10:50:00","10:51:00","10:52:00","10:53:00","10:54:00","10:55:00","10:56:00","10:57:00","10:58:00","10:59:00","11:00:00","11:01:00","11:02:00","11:03:00","11:04:00","11:05:00","11:06:00","11:07:00","11:08:00","11:09:00","11:10:00","11:11:00","11:12:00","11:13:00","11:14:00","11:15:00","11:16:00","11:17:00","11:18:00","11:19:00","11:20:00","11:21:00","11:22:00","11:23:00","11:24:00","11:25:00","11:26:00","11:27:00","11:28:00","11:29:00","11:30:00","11:31:00","11:32:00","11:33:00","11:34:00","11:35:00","11:36:00","11:37:00","11:38:00","11:39:00","11:40:00","11:41:00","11:42:00","11:43:00","11:44:00","11:45:00","11:46:00","11:47:00","11:48:00","11:49:00","11:50:00","11:51:00","11:52:00","11:53:00","11:54:00","11:55:00","11:56:00","11:57:00","11:58:00","11:59:00","12:00:00","12:01:00","12:02:00","12:03:00","12:04:00","12:05:00","12:06:00","12:07:00","12:08:00","12:09:00","12:10:00","12:11:00","12:12:00","12:13:00","12:14:00","12:15:00","12:16:00","12:17:00"," ...

# %%
uk_retail.nunique()
# Out:
# Invoice Number      23355
# Stock Code           3930
# Item Description     3804
# Quantity              702
# Timestamp           21158
# Unit Price           1879
# Customer ID          3950
# Country                 1
# Sales                7354
# Invoice Time          768
# Invoice Date          305
# Day of the week         6
# Month                  12
# Year                    2
# dtype: int64

# %% [markdown]
# ### Comparing sales of the various days of the week

# %%
day_counts = uk_retail['Day of the week'].unique()
daily_sales_counts = uk_retail.groupby('Day of the week')['Sales'].count()

plt.figure(figsize=(8, 6))
sns.barplot(x=day_counts, y=daily_sales_counts.values)
plt.xlabel('Day of the week')
plt.ylabel('Count')
plt.title('Number of Sales per Day of the Week')
plt.show()

# %%
day_sales = uk_retail['Day of the week'].unique()
daily_sales = uk_retail.groupby('Day of the week')['Sales'].sum()

plt.figure(figsize=(8, 6))
sns.barplot(x=day_sales, y=daily_sales.values)
plt.xlabel('Day of the week')
plt.ylabel('Total Sales')
plt.title('Total Sales per Day of the Week')
plt.show()

# %%
avg_day_sales = uk_retail['Day of the week'].unique()
avg_daily_sales = uk_retail.groupby('Day of the week')['Sales'].mean()

plt.figure(figsize=(8, 6))
sns.barplot(x=avg_day_sales, y=avg_daily_sales.values)
plt.xlabel('Day of the week')
plt.ylabel('Average Sales')
plt.title('Average Sales per Day of the Week')
plt.show()

# %% [markdown]
# ### Comparing sales of the various months of the year

# %%
month_sales = uk_retail['Month'].unique()
monthly_sales_count = uk_retail.groupby('Month')['Sales'].count()

plt.figure(figsize=(10, 6))
sns.barplot(x=month_sales, y=monthly_sales_count.values)
plt.xlabel('month')
plt.ylabel('Count of Sales')
plt.title('Number of monthly Sales')
plt.show()

# %%
Total_month_sales = uk_retail['Month'].unique()
Total_monthly_sales = uk_retail.groupby('Month')['Sales'].sum()

plt.figure(figsize=(10, 6))
sns.barplot(x=Total_month_sales, y=Total_monthly_sales.values)
plt.xlabel('month')
plt.ylabel('Total Sales')
plt.title('Total Monthly Sales')
plt.show()

# %% [markdown]
# ###Correlation Between Quantity and sales

# %%
uk_retail['Quantity'].corr(uk_retail['Sales'])
# Out:
# 0.5500892681896401

# %%
uk_retail['Unit Price'].corr(uk_retail['Sales'])
# Out:
# -0.104176048742056

# %% [markdown]
# ## BUSINESS QUESTIONS

# %% [markdown]
# ### Which items need to be ordered in advance for the retail store?

# %%
high_quantity_items = uk_retail.groupby('Item Description')['Quantity'].sum().sort_values(ascending=False).reset_index().head(20)
high_quantity_item = high_quantity_items['Item Description'].tolist()

high_sale_items = uk_retail.groupby('Item Description')['Sales'].sum().sort_values(ascending=False).reset_index().head(20)
high_sale_item = high_sale_items['Item Description'].tolist()

for item in high_sale_item:
  if item in high_quantity_item:
    print(item)
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER
# PARTY BUNTING
# JUMBO BAG RED RETROSPOT
# PAPER CHAIN KIT 50'S CHRISTMAS
# ASSORTED COLOUR BIRD ORNAMENT
# POPCORN HOLDER
# JUMBO BAG PINK POLKADOT
# JUMBO BAG VINTAGE DOILY
# VICTORIAN GLASS HANGING T-LIGHT

# %% [markdown]
# These have sales values found in the higher portion outliers of the sales(above 31,000 pounds) and order quantities higher than 16,000

# %% [markdown]
# ###What are the most purchased items?

# %%
high_patronage_items = uk_retail.groupby('Item Description')['Sales'].count().sort_values(ascending=False).reset_index().head(15)
high_patronage_item=(high_patronage_items['Item Description']).tolist()
high_patronage_item
# Out:
# ['WHITE HANGING HEART T-LIGHT HOLDER',
#  'JUMBO BAG RED RETROSPOT',
#  'REGENCY CAKESTAND 3 TIER',
#  'PARTY BUNTING',
#  'LUNCH BAG RED RETROSPOT',
#  'ASSORTED COLOUR BIRD ORNAMENT',
#  'POPCORN HOLDER',
#  'SET OF 3 CAKE TINS PANTRY DESIGN ',
#  'LUNCH BAG  BLACK SKULL.',
#  'NATURAL SLATE HEART CHALKBOARD ',
#  'LUNCH BAG SUKI DESIGN ',
#  'HEART OF WICKER SMALL',
#  'JUMBO BAG PINK POLKADOT',
#  'PACK OF 72 RETROSPOT CAKE CASES',
#  'JUMBO BAG VINTAGE DOILY ']

# %% [markdown]
# ###What are the least purchased items?

# %%
low_patronage_items = uk_retail.groupby('Item Description')['Sales'].count().sort_values(ascending=False).reset_index().tail(10)
low_patronage_item=(low_patronage_items['Item Description']).tolist()
low_patronage_item
# Out:
# ['BLOSSOM IMAGES SCRAP BOOK SET',
#  'WRAP BLUE RUSSIAN FOLKART',
#  'PINK/WHITE GLASS DEMI CHOKER',
#  'SET 10 CARD CHRISTMAS STAMPS 16963',
#  'RUBY GLASS CLUSTER NECKLACE',
#  'LASER CUT MULTI STRAND NECKLACE',
#  'WRAP A PRETTY THANK YOU',
#  'WRAP  PINK FLOCK',
#  'CREAM SWEETHEART TRAYS',
#  'LETTER "U" BLING KEY RING']

# %% [markdown]
# ###How many customers are there?

# %%
num_customers = (uk_retail['Customer ID'].nunique())
print('The retail store has {} customers'.format(num_customers))
# Out:
# The retail store has 3950 customers

# %% [markdown]
# ###Who are the top customers and what do they patronise?

# %% [markdown]
# ## Recency, Frequency and Monetary (RFM) Analysis

# %%
# Convert the rest of the null Customer ID's to unknown
uk_retail['Customer ID'] = uk_retail['Customer ID'].fillna("unknown")

# %%
uk_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 490157 entries, 0 to 541893
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Invoice Number    490157 non-null  object
#  1   Stock Code        490157 non-null  object
#  2   Item Description  490157 non-null  object
#  3   Quantity          490157 non-null  int64
#  4   Timestamp         490157 non-null  datetime64[ns]
#  5   Unit Price        490157 non-null  float64
#  6   Customer ID       490157 non-null  object
#  7   Country           490157 non-null  object
#  8   Sales             490157 non-null  float64
#  9   Invoice Time      490157 non-null  object
#  10  Invoice Date      490157 non-null  datetime64[ns]
#  11  Day of the week   490157 non-null  object
#  12  Month             490157 non-null  object
#  13  Year              490157 non-null  int32
# dtypes: datetime64[ns](2), float64(2), int32(1), int64(1), object(8)
# memory usage: 54.2+ MB

# %%
uk_retail['Date Today'] = date.today()
uk_retail['Date Today']=pd.to_datetime(uk_retail['Date Today'])
uk_retail['Date Today']
# Out:
# 0        2024-04-29
# 1        2024-04-29
# 2        2024-04-29
# 3        2024-04-29
# 4        2024-04-29
#             ...
# 541889   2024-04-29
# 541890   2024-04-29
# 541891   2024-04-29
# 541892   2024-04-29
# 541893   2024-04-29
# Name: Date Today, Length: 490157, dtype: datetime64[ns]

# %%
uk_retail.isna().sum()
# Out:
# Invoice Number      0
# Stock Code          0
# Item Description    0
# Quantity            0
# Timestamp           0
# Unit Price          0
# Customer ID         0
# Country             0
# Sales               0
# Invoice Time        0
# Invoice Date        0
# Day of the week     0
# Month               0
# Year                0
# Date Today          0
# dtype: int64

# %%
function_dictionary = {'Sales':'sum','Date Today':'mean','Invoice Date':'max','Stock Code':'count'}
uk_retail1 = uk_retail.groupby(['Customer ID']).aggregate(function_dictionary)

# %%
uk_retail1['Invoice Date']=pd.to_datetime(uk_retail1['Invoice Date'])

# %%
#Calculating Recency
uk_retail1['Recency'] = uk_retail1['Date Today'] - uk_retail1['Invoice Date']

# %%
# Frequency
frequency_data = uk_retail1.groupby('Customer ID')['Stock Code'].count().reset_index()
frequency_data.rename(columns= {'Stock Code': 'Frequency'}, inplace = True)
uk_retail1 = uk_retail1.merge(frequency_data, on = 'Customer ID', how = 'left')

# %%
# Monetary value
monetary_data = uk_retail1.groupby('Customer ID')['Sales'].sum().reset_index()
monetary_data.rename(columns={'Sales': 'MonetaryValue'}, inplace = True)
uk_retail1 = uk_retail1.merge(monetary_data, on = 'Customer ID', how = 'left')
uk_retail1
# Out:
#      Customer ID       Sales                    Date Today Invoice Date  \
# 0        12346.0        0.00 2024-04-29 00:00:00.000000000   2011-01-18
# 1        12747.0     4196.01 2024-04-29 00:00:00.000000000   2011-12-07
# 2        12748.0    28681.86 2024-04-29 00:00:00.000000000   2011-12-09
# 3        12749.0     3868.20 2024-04-29 00:00:00.000000000   2011-12-06
# 4        12820.0      942.34 2024-04-29 00:00:00.000000000   2011-12-06
# ...          ...         ...                           ...          ...
# 3946     18281.0       80.82 2024-04-29 00:00:00.000000000   2011-06-12
# 3947     18282.0      176.60 2024-04-29 00:00:00.000000000   2011-12-02
# 3948     18283.0     2045.53 2024-04-29 00:00:00.000000256   2011-12-06
# 3949     18287.0     1837.28 2024-04-29 00:00:00.000000000   2011-10-28
# 3950     unknown  1862951.09 2024-04-29 00:00:00.000000000   2011-12-09
#
#       Stock Code                      Recency  Frequency  MonetaryValue
# 0              2           4850 days 00:00:00          1           0.00
# 1            103           4527 days 00:00:00          1        4196.01
# 2           4459           4525 days 00:00:00          1       28681.86
# 3            231           4528 days 00:00:00          1        3868.20
# 4             59           4528 days 00:00:00          1         942.34
# ...          ...                          ...        ...            ...
# 3946           7           4705 days 00:00:00          1          80.82
# 3947          13           4532 days 00:00:00          1         176.60
# 3948         721 4528 days 00:00:00.000000256          1        2045.53
# 3949          70           4567 days 00:00:00          1        1837.28
# 3950      133432           4525 days 00:00:00          1     1862951.09
#
# [3951 rows x 8 columns]

# %%
# setting RFM scores
recency_scores = [5, 4, 3, 2, 1]
frequency_scores = [1, 2, 3, 4, 5]
monetary_scores = [1, 2, 3, 4, 5]
uk_retail1['RecencyScore'] = pd.cut(uk_retail1['Recency'], bins = 5, labels= recency_scores)
uk_retail1['FrequencyScore'] = pd.cut(uk_retail1['Frequency'], bins = 5, labels= frequency_scores)
uk_retail1['MonetaryScore'] = pd.cut(uk_retail1['MonetaryValue'], bins= 5, labels= monetary_scores)

# Converting cores into integers
uk_retail1['RecencyScore'] = uk_retail1['RecencyScore'].astype(int)
uk_retail1['FrequencyScore'] = uk_retail1['FrequencyScore'].astype(int)
uk_retail1['MonetaryScore'] = uk_retail1['MonetaryScore'].astype(int)

# %%
uk_retail1['RFM_Score'] = uk_retail1['RecencyScore'] + uk_retail1['FrequencyScore'] + uk_retail1['MonetaryScore']

uk_retail1['RFM Customer Segments'] = ''

uk_retail1.loc[uk_retail1['RFM_Score'] >= 9, 'RFM Customer Segments'] = 'Loyal Customers'
uk_retail1.loc[(uk_retail1['RFM_Score'] >= 6) & (uk_retail1['RFM_Score'] < 9), 'RFM Customer Segments'] = 'Potential Loyalists'
uk_retail1.loc[(uk_retail1['RFM_Score'] >= 5) & (uk_retail1['RFM_Score'] < 7), 'RFM Customer Segments'] = 'At-Risk Customers'
uk_retail1.loc[uk_retail1['RFM_Score'] <= 5, 'RFM Customer Segments'] = 'Lost'

# %% [markdown]
# ####DISTRIBUTION OF SEGMENTS

# %%
# Loyal Customers segment
loyal_customers_segment = uk_retail1[uk_retail1['RFM Customer Segments'] == 'Loyal Customers']
plt.figure(figsize= (10,6))
sns.boxplot(data = loyal_customers_segment[['RecencyScore', 'FrequencyScore', 'MonetaryScore']], palette= 'pastel')
plt.title('Distribution of RFM Values within Loyal Customers Segment')
plt.xlabel('RFM Attribute')
plt.ylabel('RFM Value')

plt.show()

# %% [markdown]
# The highest performing customers have a recency score of 5, frequency score 3, and monetary scores of 1.

# %%
# Potential Loyalists segment
potential_loyalists_segment = uk_retail1[uk_retail1['RFM Customer Segments'] == 'Potential Loyalists']
plt.figure(figsize= (10,6))
sns.boxplot(data = potential_loyalists_segment[['RecencyScore', 'FrequencyScore', 'MonetaryScore']], palette= 'pastel')
plt.title('Distribution of RFM Values within  Potential Loyalists Segment')
plt.xlabel('RFM Attribute')
plt.ylabel('RFM Value')
# Out:
# Text(0, 0.5, 'RFM Value')

# %%
# At-risk Customers segment
arc_segment = uk_retail1[uk_retail1['RFM Customer Segments'] == 'At-Risk Customers']
plt.figure(figsize= (10,6))
sns.boxplot(data = arc_segment[['RecencyScore', 'FrequencyScore', 'MonetaryScore']], palette= 'pastel')
plt.title('Distribution of RFM Values within  At-risk Customers Segment')
plt.xlabel('RFM Attribute')
plt.ylabel('RFM Value')
# Out:
# Text(0, 0.5, 'RFM Value')

# %%
# Lost Customers segment
lost_segment = uk_retail1[uk_retail1['RFM Customer Segments'] == 'Lost']
plt.figure(figsize= (10,6))
sns.boxplot(data = lost_segment[['RecencyScore', 'FrequencyScore', 'MonetaryScore']], palette= 'pastel')
plt.title('Distribution of RFM Values within Lost Segment')
plt.xlabel('RFM Attribute')
plt.ylabel('RFM Value')
# Out:
# Text(0, 0.5, 'RFM Value')

# %% [markdown]
# ###Comparism of Segments

# %%
# Distribution of customers over all segments
segment_counts = uk_retail1['RFM Customer Segments'].value_counts()
plt.figure(figsize=(10,6))
sns.barplot(x = segment_counts.index, y=segment_counts.values, palette= 'pastel')
plt.title('RFM Customer Segments')
plt.xlabel('RFM Segments')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# ###How many customers does each segment contain

# %%
segment_counts
# Out:
# RFM Customer Segments
# Loyal Customers        2463
# Potential Loyalists     924
# At-Risk Customers       319
# Lost                    245
# Name: count, dtype: int64

# %% [markdown]
# ###Comparism of Sales by Segments

# %%
segment_sum = uk_retail1.groupby('RFM Customer Segments')['Sales'].sum()
plt.figure(figsize=(10,6))
sns.barplot(x = segment_sum.index, y=segment_sum.values, palette= 'pastel')
plt.title('Sales by Customer Segments')
plt.xlabel('RFM Segments')
plt.ylabel('Sum of Sales')
plt.show()

# %% [markdown]
# ###How much sales does each segment generate

# %%
segment_sum
# Out:
# RFM Customer Segments
# At-Risk Customers       142734.940
# Lost                     73289.310
# Loyal Customers        7737706.852
# Potential Loyalists     664142.202
# Name: Sales, dtype: float64

# %% [markdown]
# ## RECOMMENDATIONS
# 1. Promotions should be run on less patronized objects
# 2. Discounts for bulk purchases should be given
# 3. The retail shop may reward loyal customers with special offers and freebies of the less purchased items.
# 4. Organize sales at peak times to draw more customers.
